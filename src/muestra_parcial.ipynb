# %%
import matplotlib.pyplot as plt

salida_raw = [
    "Epoch 0  Loss train 0.0188  IoU train 0.2724",
    "Epoch 0  Loss valid 0.0023  IoU valid 0.3568 ",
    "Epoch 1  Loss train 0.0014  IoU train 0.3342 ",
    "Epoch 1  Loss valid 0.0025  IoU valid 0.3192 ",
    "Epoch 2  Loss train 0.0011  IoU train 0.3683 ",
    "Epoch 2  Loss valid 0.0023  IoU valid 0.3599 ",
    "Epoch 3  Loss train 0.0010  IoU train 0.3796 ",
    "Epoch 3  Loss valid 0.0024  IoU valid 0.3399 ",
    "Epoch 4  Loss train 0.0009  IoU train 0.3975 ",
    "Epoch 4  Loss valid 0.0023  IoU valid 0.3251 ",
    "Epoch 5  Loss train 0.0008  IoU train 0.4113 ",
    "Epoch 5  Loss valid 0.0022  IoU valid 0.3875 ",
    "Epoch 6  Loss train 0.0007  IoU train 0.4228 ",
    "Epoch 6  Loss valid 0.0024  IoU valid 0.3601 ",
    "Epoch 7  Loss train 0.0006  IoU train 0.4274 ",
    "Epoch 7  Loss valid 0.0022  IoU valid 0.3754 ",
    "Epoch 8  Loss train 0.0006  IoU train 0.4448 ",
    "Epoch 8  Loss valid 0.0026  IoU valid 0.3114 ",
    "Epoch 9  Loss train 0.0005  IoU train 0.4596 ",
    "Epoch 9  Loss valid 0.0025  IoU valid 0.3188 ",
    "Epoch 10  Loss train 0.0005  IoU train 0.4603", 
    "Epoch 10  Loss valid 0.0023  IoU valid 0.3776", 
    "Epoch 11  Loss train 0.0004  IoU train 0.4816", 
    "Epoch 11  Loss valid 0.0022  IoU valid 0.3739", 
    "Epoch 12  Loss train 0.0004  IoU train 0.4939", 
    "Epoch 12  Loss valid 0.0022  IoU valid 0.3769", 
    "Epoch 13  Loss train 0.0004  IoU train 0.4943", 
    "Epoch 13  Loss valid 0.0024  IoU valid 0.3597", 
    "Epoch 14  Loss train 0.0003  IoU train 0.5219", 
    "Epoch 14  Loss valid 0.0024  IoU valid 0.3338", 
    "Epoch 15  Loss train 0.0003  IoU train 0.5339", 
    "Epoch 15  Loss valid 0.0024  IoU valid 0.3273", 
    "Epoch 16  Loss train 0.0003  IoU train 0.5337", 
    "Epoch 16  Loss valid 0.0025  IoU valid 0.3296", 
    "Epoch 17  Loss train 0.0002  IoU train 0.5632", 
    "Epoch 17  Loss valid 0.0024  IoU valid 0.3248", 
    "Epoch 18  Loss train 0.0002  IoU train 0.5744", 
    "Epoch 18  Loss valid 0.0026  IoU valid 0.3078", 
    "Epoch 19  Loss train 0.0002  IoU train 0.6005", 
    "Epoch 19  Loss valid 0.0022  IoU valid 0.3765", 
    "Epoch 20  Loss train 0.0002  IoU train 0.6070", 
    "Epoch 20  Loss valid 0.0025  IoU valid 0.3011", 
    "Epoch 21  Loss train 0.0001  IoU train 0.6170", 
    "Epoch 21  Loss valid 0.0024  IoU valid 0.3210", 
    "Epoch 22  Loss train 0.0001  IoU train 0.6242", 
    "Epoch 22  Loss valid 0.0027  IoU valid 0.2877", 
    "Epoch 23  Loss train 0.0001  IoU train 0.6326", 
    "Epoch 23  Loss valid 0.0022  IoU valid 0.3831", 
    "Epoch 24  Loss train 0.0001  IoU train 0.6387", 
    "Epoch 24  Loss valid 0.0024  IoU valid 0.3292", 
    "Epoch 25  Loss train 0.0001  IoU train 0.6289", 
    "Epoch 25  Loss valid 0.0022  IoU valid 0.3648", 
    "Epoch 26  Loss train 0.0001  IoU train 0.6499", 
    "Epoch 26  Loss valid 0.0024  IoU valid 0.3438", 
    "Epoch 27  Loss train 0.0001  IoU train 0.6442", 
    "Epoch 27  Loss valid 0.0022  IoU valid 0.3726", 
    "Epoch 28  Loss train 0.0001  IoU train 0.6393", 
    "Epoch 28  Loss valid 0.0024  IoU valid 0.3475", 
    "Epoch 29  Loss train 0.0001  IoU train 0.6519", 
    "Epoch 29  Loss valid 0.0025  IoU valid 0.3486", 
    "Epoch 30  Loss train 0.0001  IoU train 0.6558", 
    "Epoch 30  Loss valid 0.0023  IoU valid 0.3460", 
    "Epoch 31  Loss train 0.0001  IoU train 0.6611", 
    "Epoch 31  Loss valid 0.0022  IoU valid 0.3794", 
    "Epoch 32  Loss train 0.0001  IoU train 0.6624", 
    "Epoch 32  Loss valid 0.0026  IoU valid 0.3095", 
    "Epoch 33  Loss train 0.0001  IoU train 0.6701", 
    "Epoch 33  Loss valid 0.0026  IoU valid 0.3031", 
    "Epoch 34  Loss train 0.0001  IoU train 0.6698", 
    "Epoch 34  Loss valid 0.0023  IoU valid 0.3598", 
    "Epoch 35  Loss train 0.0001  IoU train 0.6694", 
    "Epoch 35  Loss valid 0.0023  IoU valid 0.3593", 
    "Epoch 36  Loss train 0.0001  IoU train 0.6787", 
    "Epoch 36  Loss valid 0.0022  IoU valid 0.3560", 
    "Epoch 37  Loss train 0.0001  IoU train 0.6905", 
    "Epoch 37  Loss valid 0.0023  IoU valid 0.3583", 
    "Epoch 38  Loss train 0.0001  IoU train 0.6828", 
    "Epoch 38  Loss valid 0.0025  IoU valid 0.3262", 
    "Epoch 39  Loss train 0.0001  IoU train 0.6822", 
    "Epoch 39  Loss valid 0.0025  IoU valid 0.3160", 
    "Epoch 40  Loss train 0.0001  IoU train 0.6895", 
    "Epoch 40  Loss valid 0.0023  IoU valid 0.3452", 
    "Epoch 41  Loss train 0.0001  IoU train 0.6949", 
    "Epoch 41  Loss valid 0.0023  IoU valid 0.3500", 
    "Epoch 42  Loss train 0.0001  IoU train 0.7011", 
    "Epoch 42  Loss valid 0.0025  IoU valid 0.3162", 
    "Epoch 43  Loss train 0.0001  IoU train 0.7023", 
    "Epoch 43  Loss valid 0.0025  IoU valid 0.3230", 
    "Epoch 44  Loss train 0.0001  IoU train 0.7064", 
    "Epoch 44  Loss valid 0.0022  IoU valid 0.3647", 
    "Epoch 45  Loss train 0.0001  IoU train 0.7026", 
    "Epoch 45  Loss valid 0.0024  IoU valid 0.3449", 
    "Epoch 46  Loss train 0.0001  IoU train 0.7076", 
    "Epoch 46  Loss valid 0.0025  IoU valid 0.3228",
    ]

iou_train = []
iou_valid = []
loss_valid = []
loss_train = []

for log in salida_raw:
    if "Loss valid" in log:
        parts = log.split()
        loss_idx = parts.index("valid") + 1
        loss_valid.append(float(parts[loss_idx]))
    if "IoU valid" in log:
        parts = log.split()
        iou_idx = parts.index("valid", parts.index("IoU")) + 1
        iou_valid.append(float(parts[iou_idx]))
    if "Loss train" in log:
        parts = log.split()
        loss_idx = parts.index("train") + 1
        loss_train.append(float(parts[loss_idx]))
    if "IoU train" in log:
        parts = log.split()
        iou_idx = parts.index("train", parts.index("IoU")) + 1
        iou_train.append(float(parts[iou_idx]))

num_epoch = len(loss_train)

print(iou_train)
print(iou_valid)

# Graficar la evolución de la Loss durante el entrenamiento y validación
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)  # Subgráfico 1: Loss
plt.plot(range(num_epoch), loss_train, label='Loss train', color='blue')
plt.plot(range(num_epoch), loss_valid, label='Loss valid', color='red')
plt.title('Loss durante el entrenamiento y validación')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# Graficar la evolución de la IoU durante el entrenamiento y validación
plt.subplot(1, 2, 2)  # Subgráfico 2: IoU
plt.plot(range(num_epoch), iou_train, label='IoU train', color='blue')
plt.plot(range(num_epoch), iou_valid, label='IoU valid', color='red')
plt.title('IoU durante el entrenamiento y validación')
plt.xlabel('Épocas')
plt.ylabel('IoU')
plt.legend()

plt.tight_layout()

# Mostrar ambas gráficas
plt.show()
# Out:
# [0.2724, 0.3342, 0.3683, 0.3796, 0.3975, 0.4113, 0.4228, 0.4274, 0.4448, 0.4596, 0.4603, 0.4816, 0.4939, 0.4943, 0.5219, 0.5339, 0.5337, 0.5632, 0.5744, 0.6005, 0.607, 0.617, 0.6242, 0.6326, 0.6387, 0.6289, 0.6499, 0.6442, 0.6393, 0.6519, 0.6558, 0.6611, 0.6624, 0.6701, 0.6698, 0.6694, 0.6787, 0.6905, 0.6828, 0.6822, 0.6895, 0.6949, 0.7011, 0.7023, 0.7064, 0.7026, 0.7076]
# [0.3568, 0.3192, 0.3599, 0.3399, 0.3251, 0.3875, 0.3601, 0.3754, 0.3114, 0.3188, 0.3776, 0.3739, 0.3769, 0.3597, 0.3338, 0.3273, 0.3296, 0.3248, 0.3078, 0.3765, 0.3011, 0.321, 0.2877, 0.3831, 0.3292, 0.3648, 0.3438, 0.3726, 0.3475, 0.3486, 0.346, 0.3794, 0.3095, 0.3031, 0.3598, 0.3593, 0.356, 0.3583, 0.3262, 0.316, 0.3452, 0.35, 0.3162, 0.323, 0.3647, 0.3449, 0.3228]

# %%
import timm

vit_models = timm.list_models('*vit*')
for model in vit_models:
    print(model)
# Out:
# ['convit_base', 'convit_small', 'convit_tiny', 'crossvit_9_240', 'crossvit_9_dagger_240', 'crossvit_15_240', 'crossvit_15_dagger_240', 'crossvit_15_dagger_408', 'crossvit_18_240', 'crossvit_18_dagger_240', 'crossvit_18_dagger_408', 'crossvit_base_240', 'crossvit_small_240', 'crossvit_tiny_240', 'gcvit_base', 'gcvit_small', 'gcvit_tiny', 'gcvit_xtiny', 'gcvit_xxtiny', 'levit_128', 'levit_128s', 'levit_192', 'levit_256', 'levit_256d', 'levit_384', 'maxvit_base_224', 'maxvit_large_224', 'maxvit_nano_rw_256', 'maxvit_pico_rw_256', 'maxvit_rmlp_nano_rw_256', 'maxvit_rmlp_pico_rw_256', 'maxvit_rmlp_small_rw_224', 'maxvit_rmlp_small_rw_256', 'maxvit_rmlp_tiny_rw_256', 'maxvit_small_224', 'maxvit_tiny_224', 'maxvit_tiny_pm_256', 'maxvit_tiny_rw_224', 'maxvit_tiny_rw_256', 'maxvit_xlarge_224', 'maxxvit_rmlp_nano_rw_256', 'maxxvit_rmlp_small_rw_256', 'maxxvit_rmlp_tiny_rw_256', 'mobilevit_s', 'mobilevit_xs', 'mobilevit_xxs', 'mobilevitv2_050', 'mobilevitv2_075', 'mobilevitv2_100', 'mobilevitv2
# ...
