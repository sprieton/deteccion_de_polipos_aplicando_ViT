# %% [markdown]
# # Evaluación y Uso de ViT-Large para detección de pólipos
#
# ## Introducción
#
# En este notebook, exploramos y evaluamos el rendimiento del modelo [ViT-Large](https://pprp.github.io/timm/models/vision-transformer/)
# para la detección de pólipos cancerosos en imágen médica de colonoscopias.
#
# Para ello utilizaremos el dataset de [**Piccolo**](https://huggingface.co/hustvl/yolos-base),
# este dataset proporciona imágenes de colonoscopias tanto en RGB como en NBI.
# Para la detección **modificaremos el modelo** el modelo para detectar los pólipos
# usando bboxes.
#
# ### Problema
#
# Ya estudiadas una serie de arquitecturas hemos llegado a un problema, las arquitecturars ViT no generalizan correctamente, y no conseguimos **resultados mayores de 50% en validación**.
#
# **La hipótesis** es que las arquitecturas no sean capaces de mejorar debido a que **los patrones son muy compolejos**, y es posible que **un modelo con más parámetros** sea capaz de mejorar esos resultados.
#
# ### Objetivos
#
# - Modificar el modelo **ViT-Large** para la detección de pópipos con bounding boxes.
# - Entrenar el modelo con las imágenes medicas seleccionadas haciendo un **fine-tunning** para imágen médica.
# - Mostar el rendimiento del mismo con el benchamark del modelo seleccionado
#
# ¡Comencemos con la evaluación del modelo!
# ## Pasos a seguir
#
# 1. Cargamos y analizamos el **dataset**
# 2. **Procesamos los datos** para cumplir con el formato de entrada del modelo
# 3. Cargamos y **modificamos el modelo** para detección de pólipos
# 4. **Entrenamos** el modelo con los datos obtenidos
# 4. **Evaluamos** el rendimiento
#
# ### 1- Cargar y analizar el dataset
#
# Como hemos mencionado cargaremos el datset de [**Piccolo**](https://www.biobancovasco.bioef.eus/en/Sample-and-data-catalog/Databases/PD178-PICCOLO-EN.html),
# el cuál tiene una cantidad rezonable de imágenes en RGB y NBI categorizadas por
# al pólipo al que pertenecen por lo que podemos usar la división pre hecha del dataset
# y evitar asignar frames del mismo pólipo al train y validation invalidando los relustados.
#
# Además mostraré informaciñon relevante de las imágenes escogidas

# %%
import sys
import os

path_to_add = os.path.abspath('../../utils')
if path_to_add not in sys.path:
    sys.path.append(path_to_add)

from utils import ImageDatasetProcessor as idp

DS_PATH = "../../datasets"
DS_NAME = "Piccolo"
json_path = f"{DS_PATH}/piccolo_dataset/{DS_NAME}_dict.json"

# paths del dataset
paths_img = [
    # train paths
    (DS_PATH + "/piccolo_dataset/test/polyps",                      # polyps
     DS_PATH + "/piccolo_dataset/test/masks",                       # masks
     DS_PATH + "/piccolo_dataset/test/void", "test"  ,              # voids
     DS_PATH + "/piccolo_dataset/listado_WL-NBI_Piccolo.csv"),      # light type

    # test paths
    (DS_PATH + "/piccolo_dataset/train/polyps",
     DS_PATH + "/piccolo_dataset/train/masks",
     DS_PATH + "/piccolo_dataset/train/void", "train",
     DS_PATH + "/piccolo_dataset/listado_WL-NBI_Piccolo.csv"),

    # validation paths
    (DS_PATH + "/piccolo_dataset/validation/polyps",
     DS_PATH + "/piccolo_dataset/validation/masks",
     DS_PATH + "/piccolo_dataset/validation/void", "validation",
     DS_PATH + "/piccolo_dataset/listado_WL-NBI_Piccolo.csv")]

# inicializamos el dataset con su nombre y fichero de formatos de imagen
dt_Piccolo = idp(target_resolution=(400, 240), dataset_name=DS_NAME,
                     json_path=json_path)

# procesamos el dataset si no existe el json
if not os.path.isfile(json_path):
    for path in paths_img:
        print(f"procesando conjunto: {path[3]}")
        dt_Piccolo.load_dataset(path[0], path[1], voids_path=path[2], 
                                split=path[3], light_csv=path[4])

# %% [markdown]
# #### Análisis del dataset
# Como podemos ver es un dataset muy ordenado, con una cantidad representativa de
# imágenes NBI por lo que es adecuado para el entrenamiento en ambos tipos de luz
# (WL, NBI).
#
# Además podemos observar que es un dataset con una distribución de los pólipos
# más o menos descentralizada.

# %%
dt_Piccolo.print_summary()
# Out:
# Total imágenes: 3433
# Composición del dataset:
# Resoluciónes: total distintas resoluciones 2
# 	480x854: 1972	1080x1920: 1461
#
# Tipos de luz:
# 	WL: 2131	NBI: 1302
#
# Splits:
# 	test: 333	train: 2203	validation: 897
#
# Canales:
# 	polyp_RGB: 3433	mask_L: 3433	void_L: 3433
#
# Volumen medio de los pólipos respecto a la imagen:	20.195122875106236%
# Distancia media del centro del pólipos al centro de la imagen:	59.03986288688952px

# %%
dt_Piccolo.graph_summmary()

# %% [markdown]
# Finalmente veamos una muestra de una imágen aleatoria y su aspecto con la bbox

# %%
import random

# mostramos aleatoriamente una imágen del dataset
rand_key = random.choice(list(dt_Piccolo.dict.keys()))
dt_Piccolo.show_image(rand_key)
# Out:
# Imagen 003_VP3_frame0464.png	bbox: (335, 310, 129, 103)

# %% [markdown]
# ## Entrenamiento de ViT-Large
#
# Para esta segunda entrenaremos el modelo de [ViT-Large](https://pprp.github.io/timm/models/vision-transformer/) **de la librería timm**,
# con las imágenes del dataset de Piccolo, con la peculiaridad que trataremos con
# un modelo modificado para devolver solo las bboxes.
#
# #### Pasos del entrenemiento
# 1. **Modificaremos el modelo** para entrenar y devolver tan solo las bboxes ya que
# ViT-Large ofrece la arquitectura del encoder ViT por lo que **añadiremos un head de detección**, en este caso una **MLP**, que devuelva las bboxes
#
# 2. **Preparar todo para el entrenamiento**, esto son elementos como el
# optimizador y la función de pérdida además de juntar definitivamente los datos
# en los splits adecuados y DataLoaders para usarlos en la función de entrenamiento
#
# 3. **Entrenar** el modelo y ir obteniendo datos del rendimiento del mismo para
# poder mostrarlos más adelante

# %%
from transformers import YolosForObjectDetection
import torch.nn as nn
import torch

# Creamos una cabeza de deteccion siguiendo el formato de YOLO
class BBoxMLP(nn.Module):
    def __init__(self, in_features=1024, hidden_dim=384, out_features=4):
        super(BBoxMLP, self).__init__()
        
        # Creamos la MLP de detección
        self.mlp = nn.Sequential(
            nn.Linear(in_features, hidden_dim),     # capa de entrada
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),      # capa intermedia
            nn.ReLU(),
            nn.Linear(hidden_dim, out_features)     # capa de salida
        )

    # debemos definir el forward ya que heredamos de nn.Module
    def forward(self, x):
        return self.mlp(x)  # ejecuta la sentencia de mlp

# Modificamos la arquitectura ViT-large para detectar con la cabeza BBoxMLP
class ViTs4Detection(nn.Module):
    def __init__(self, vit_model, bbox_head):
        super(ViTs4Detection, self).__init__()  # iniciamos la clase padre antes de nada
        
        self.vit = vit_model
        self.head_bbox = bbox_head

    def forward(self, x):
        # x es la entrada de la imagen
        features = self.vit(x)      # ejecutamos la vit
        # forma de salida (batch_size, 1024) -> ya tenemos los CLS
        bboxes = self.head_bbox(features)

        return {'pred_bboxes': bboxes}

# %% [markdown]
# #### Preparar el entrenamiento
# Una vez modificado el modelo solo debemos preparar el entrenamiento, es decir:
# - Definir los dataloders
# - Cargar el modelo personaliazdo
# - Definir las funciones de pérdida y optimizadores
# - Definir una fuinciñon de entrenamiento
#
# Utilizaremos el **optimizador Adalain** ya que es el usado en Yolos-base y la
# **loss fuction smooth_l1_loss** para las bbox de la salida ya que es información contínua

# %%
import timm
import torch.nn as nn

# Cargamos el modelo de la librería timm
vit_S = timm.create_model('vit_large_patch16_384', pretrained=True, num_classes=0)

# # creamos el modelo con la cabeza personalizada de detección
model = ViTs4Detection(vit_S, BBoxMLP())
model.train()
# Out:
# ViTs4Detection(
#   (vit): VisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 1024, kernel_size=(16, 16), stride=(16, 16))
#       (norm): Identity()
#     )
#     (pos_drop): Dropout(p=0.0, inplace=False)
#     (norm_pre): Identity()
#     (blocks): Sequential(
#       (0): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (1): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (2): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (3): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (4): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (5): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (6): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (7): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (8): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (9): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (10): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (11): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (12): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (13): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (14): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (15): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (16): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (17): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (18): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (19): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (20): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (21): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (22): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#       (23): Block(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): Attention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): Identity()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (drop1): Dropout(p=0.0, inplace=False)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (drop2): Dropout(p=0.0, inplace=False)
#         )
#         (ls2): Identity()
#         (drop_path2): Identity()
#       )
#     )
#     (norm): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#     (fc_norm): Identity()
#     (head): Identity()
#   )
#   (head_bbox): BBoxMLP(
#     (mlp): Sequential(
#       (0): Linear(in_features=1024, out_features=384, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=384, out_features=384, bias=True)
#       (3): ReLU()
#       (4): Linear(in_features=384, out_features=4, bias=True)
#     )
#   )
# )

# %% [markdown]
# #### Entrenamiento
#
# Ahora por fin pasamos a entrenar el modelo y recopilar los dátos de análisis
# para ellos obtenemos el IoU de las bboxes, ya que al ser areas en al imágen no
# podemos medir un "accuracy" tal cual.
#
# **IoU** es una métrica usada para este
# tipo de situaciones en las que se calcula: **IoU=Area_interseccion/Area_union**
# por lo que es importante tener en cuenta que **un IoU 1 es una coincidencia exacta**

# %%
from utils import TrainModel as trm
from torch.optim import AdamW
import json

# definimos los parametros del entrenamiento 🏃‍♂
MODEL_NAME = "ViT-Large"
NUM_EPOCH = 50              # 🔄 Numero de epocas del entrenamiento 
BATCH_SIZE = 10             # 👝 Numero de imágenes por batch
TRAIN_RES = (384, 384)      # 📷 Resolucion entreno
RESULTS_JSON = f"../../resultados/{DS_NAME}_{MODEL_NAME}_{NUM_EPOCH}EP_{TRAIN_RES[0]}x{TRAIN_RES[1]}.json"
RESULTS_IMG = f"../../resultados/{DS_NAME}_{MODEL_NAME}_{NUM_EPOCH}EP_{TRAIN_RES[0]}x{TRAIN_RES[1]}.png"
json_exists = False     # flag para comprobar si tnemos un json

# Obtener los diccionarios con formato de entrenamiento
train_loader, val_loader, test_loader = dt_Piccolo.get_dataloaders(
                                            BATCH_SIZE, 
                                            use_premade_splits=True)

# definimos el optimizador y la loss function
def loss_fn(target, pred):
    return nn.functional.smooth_l1_loss(pred, target)

optimizer = AdamW(model.parameters(), lr=5e-5)
trainer = trm(model, loss_fn=loss_fn, optim=optimizer)

# si ya tenemos los resulados no volvemos a entrenar
if os.path.isfile(RESULTS_JSON):
    with open(RESULTS_JSON, "r", encoding="utf-8") as json_file:
            train_results = json.load(json_file)
    json_exists = True

if not json_exists:
    train_results = trainer.train_model(NUM_EPOCH, TRAIN_RES, 
                                    train_loader, val_loader, test_loader)

    # guardamos los datos
    with open(RESULTS_JSON, "w", encoding="utf-8") as json_file:
        json.dump(train_results, json_file)  # `indent=4` para formato legible
# Out:
# Entrenando en GPU 2
# /home/sprieto/deteccion_de_polipos_aplicando_ViT/utils/utils.py:721: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# /home/sprieto/deteccion_de_polipos_aplicando_ViT/utils/utils.py:745: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Epoch 0  Loss train 0.0011  IoU train 0.3895
# Epoch 0  Loss valid 0.0017  IoU valid 0.3756
# Epoch 1  Loss train 0.0004  IoU train 0.5243
# Epoch 1  Loss valid 0.0015  IoU valid 0.5321
# Epoch 2  Loss train 0.0003  IoU train 0.5994
# Epoch 2  Loss valid 0.0014  IoU valid 0.5277
# Epoch 3  Loss train 0.0002  IoU train 0.6426
# Epoch 3  Loss valid 0.0012  IoU valid 0.5161
# Epoch 4  Loss train 0.0001  IoU train 0.6707
# Epoch 4  Loss valid 0.0012  IoU valid 0.5402
# Epoch 5  Loss train 0.0001  IoU train 0.6625
# Epoch 5  Loss valid 0.0012  IoU valid 0.5511
# Epoch 6  Loss train 0.0001  IoU train 0.7018
# Epoch 6  Loss valid 0.0012  IoU valid 0.5366
# Epoch 7  Loss train 0.0001  IoU train 0.7057
# Epoch 7  Loss valid 0.0012  IoU valid 0.4882
# Epoch 8  Loss train 0.0001  IoU train 0.6851
# Epoch 8  Loss valid 0.0013  IoU valid 0.5051
# Epoch 9  Loss train 0.0001  IoU train 0.7396
# Epoch 9  Loss valid 0.0012  IoU valid 0.5798
# Epoch 10  Loss train 0.0001  IoU train 0.7471
# Epoch 10  Loss valid 0.0012  IoU valid 0.5187
# Epoch 11  Loss train 0.0001  IoU train 0.7508
# Epoch 11  Loss valid 0.0019  IoU valid 0.4059
# Epoch 12  Loss train 0.0004  IoU train 0.5700
# Epoch 12  Loss valid 0.0019  IoU valid 0.5160
# Epoch 13  Loss train 0.0002  IoU train 0.6377
# Epoch 13  Loss valid 0.0014  IoU valid 0.5334
# Epoch 14  Loss train 0.0001  IoU train 0.6784
# Epoch 14  Loss valid 0.0013  IoU valid 0.5314
# Epoch 15  Loss train 0.0001  IoU train 0.7274
# Epoch 15  Loss valid 0.0012  IoU valid 0.5563
# Epoch 16  Loss train 0.0001  IoU train 0.7679
# Epoch 16  Loss valid 0.0012  IoU valid 0.5628
# Epoch 17  Loss train 0.0000  IoU train 0.7923
# Epoch 17  Loss valid 0.0011  IoU valid 0.5752
# Epoch 18  Loss train 0.0000  IoU train 0.8283
# Epoch 18  Loss valid 0.0011  IoU valid 0.5764
# Epoch 19  Loss train 0.0000  IoU train 0.8524
# Epoch 19  Loss valid 0.0011  IoU valid 0.5760
# Epoch 20  Loss train 0.0000  IoU train 0.8624
# Epoch 20  Loss valid 0.0011  IoU valid 0.5626
# Epoch 21  Loss train 0.0000  IoU train 0.8699
# Epoch 21  Loss valid 0.0011  IoU valid 0.5802
# Epoch 22  Loss train 0.0000  IoU train 0.8694
# Epoch 22  Loss valid 0.0011  IoU valid 0.5749
# Epoch 23  Loss train 0.0000  IoU train 0.8692
# Epoch 23  Loss valid 0.0011  IoU valid 0.5813
# Epoch 24  Loss train 0.0000  IoU train 0.8493
# Epoch 24  Loss valid 0.0011  IoU valid 0.5603
# Epoch 25  Loss train 0.0000  IoU train 0.8517
# Epoch 25  Loss valid 0.0011  IoU valid 0.5760
# Epoch 26  Loss train 0.0000  IoU train 0.8316
# Epoch 26  Loss valid 0.0011  IoU valid 0.5752
# Epoch 27  Loss train 0.0000  IoU train 0.8175
# Epoch 27  Loss valid 0.0011  IoU valid 0.5716
# Epoch 28  Loss train 0.0000  IoU train 0.8098
# Epoch 28  Loss valid 0.0011  IoU valid 0.5651
# Epoch 29  Loss train 0.0000  IoU train 0.8083
# Epoch 29  Loss valid 0.0011  IoU valid 0.5626
# Epoch 30  Loss train 0.0000  IoU train 0.8059
# Epoch 30  Loss valid 0.0012  IoU valid 0.6133
# Epoch 31  Loss train 0.0000  IoU train 0.7686
# Epoch 31  Loss valid 0.0013  IoU valid 0.5565
# Epoch 32  Loss train 0.0001  IoU train 0.7201
# Epoch 32  Loss valid 0.0012  IoU valid 0.5300
# Epoch 33  Loss train 0.0003  IoU train 0.6266
# Epoch 33  Loss valid 0.0015  IoU valid 0.3933
# Epoch 34  Loss train 0.0003  IoU train 0.6054
# Epoch 34  Loss valid 0.0013  IoU valid 0.4966
# Epoch 35  Loss train 0.0001  IoU train 0.6829
# Epoch 35  Loss valid 0.0011  IoU valid 0.5918
# Epoch 36  Loss train 0.0001  IoU train 0.7489
# Epoch 36  Loss valid 0.0012  IoU valid 0.5528
# Epoch 37  Loss train 0.0000  IoU train 0.8050
# Epoch 37  Loss valid 0.0011  IoU valid 0.5590
# Epoch 38  Loss train 0.0000  IoU train 0.8415
# Epoch 38  Loss valid 0.0011  IoU valid 0.5856
# Epoch 39  Loss train 0.0000  IoU train 0.8655
# Epoch 39  Loss valid 0.0011  IoU valid 0.5556
# Epoch 40  Loss train 0.0000  IoU train 0.8849
# Epoch 40  Loss valid 0.0011  IoU valid 0.5843
# Epoch 41  Loss train 0.0000  IoU train 0.8812
# Epoch 41  Loss valid 0.0011  IoU valid 0.5668
# Epoch 42  Loss train 0.0000  IoU train 0.8892
# Epoch 42  Loss valid 0.0011  IoU valid 0.5682
# Epoch 43  Loss train 0.0000  IoU train 0.8905
# Epoch 43  Loss valid 0.0011  IoU valid 0.5573
# Epoch 44  Loss train 0.0000  IoU train 0.8786
# Epoch 44  Loss valid 0.0011  IoU valid 0.5654
# Epoch 45  Loss train 0.0000  IoU train 0.8700
# Epoch 45  Loss valid 0.0011  IoU valid 0.5615
# Epoch 46  Loss train 0.0000  IoU train 0.8568
# Epoch 46  Loss valid 0.0010  IoU valid 0.5788
# Epoch 47  Loss train 0.0000  IoU train 0.8444
# Epoch 47  Loss valid 0.0010  IoU valid 0.5900
# Epoch 48  Loss train 0.0000  IoU train 0.8497
# Epoch 48  Loss valid 0.0011  IoU valid 0.5589
# Epoch 49  Loss train 0.0000  IoU train 0.8183
# Epoch 49  Loss valid 0.0011  IoU valid 0.5543
# End of training!
# -------------------- FINAL RESULTS ------------------------
# |     - Test loss:     0.0009409807449764064                         |
# |     - Test IoU: 0.470702756721353                         |
# -----------------------------------------------------------

# %% [markdown]
# ## Análisis de los resultados
#
# Una vez entrenado el modelo y finalizada la obtencion de datos durante el entrenamiento,
# además de disponer de los datos de test vamos a graficar los resultados y ver
# que tal ha ido el entrenamiento.

# %%
trainer.show_results(train_results, save_img=True, img_name=RESULTS_IMG)
# Out:
# End of training!
# -------------------- FINAL RESULTS ------------------------
# |     - Test loss:     0.0009409807449764064                         |
# |     - Test IoU: 0.470702756721353                         |
# -----------------------------------------------------------
